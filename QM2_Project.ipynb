# %% [markdown]
# <a href="https://colab.research.google.com/github/Btotheshlz/QM2/blob/main/QM2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
gunLaws = {
    'Year': [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'CaliforniaLaw': [58, 57, 57, 69, 69, 69, 70, 70, 71, 85, 86, 93, 93, 93, 93, 93, 93, 93, 93, 93, 94, 95, 99, 100, 102, 104, 106, 109, 111, 111],
    'MedianLaw': [13, 14, 13.5, 15.5, 15.5, 15.5, 15.5, 15.5, 15, 15, 16.5, 16.5, 16, 16, 15, 14.5, 14, 14, 14.5, 14.5, 14, 14, 14.5, 14.5, 15.5, 15.5, 17, 18.5, 19.5, 20.5]
}
TableLaws = pd.DataFrame(gunLaws)
print(TableLaws)
# Out:
#     Year  CaliforniaLaw  MedianLaw
# 0   1991             58       13.0
# 1   1992             57       14.0
# 2   1993             57       13.5
# 3   1994             69       15.5
# 4   1995             69       15.5
# 5   1996             69       15.5
# 6   1997             70       15.5
# 7   1998             70       15.5
# 8   1999             71       15.0
# 9   2000             85       15.0
# 10  2001             86       16.5
# 11  2002             93       16.5
# 12  2003             93       16.0
# 13  2004             93       16.0
# 14  2005             93       15.0
# 15  2006             93       14.5
# 16  2007             93       14.0
# 17  2008             93       14.0
# 18  2009             93       14.5
# 19  2010             93       14.5
# 20  2011             94       14.0
# 21  2012             95       14.0
# 22  2013             99       14.5
# 23  2014            100       14.5
# 24  2015            102       15.5
# 25  2016            104       15.5
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Liniendiagramm erstellen
plt.figure(figsize=(10, 6))

# Linie für CaliforniaLaw
plt.plot(TableLaws['Year'], TableLaws['CaliforniaLaw'], label='Gun Laws in California', color='blue', marker='o')

# Linie für MedianLaws
plt.plot(TableLaws['Year'], TableLaws['MedianLaw'], label='Median Gun Laws of all States in America', color='green', marker='o')


# Diagramm beschriften
plt.xlabel('Year')
plt.ylabel('Gun Laws')
plt.title('California vs. Median Gun Laws in America over Time')

# Legende anzeigen
plt.legend()

# Diagramm anzeigen
plt.show()

# %%
LawDeath = {
    'State': ["Alaska", "Mississippi", "Wyoming", "Alabama", "Louisiana", "New Mexico", "Missouri", "Montana", "Oklahoma", "Arkansas", "South Carolina", "Tennessee", "West Virginia", "Georgia", "Ariozona", "Kentucky", "Idaho", "Kansas", "Indiana", "Nevada", "Colorado", "South Dakota", "Ohio", "Utha", "North Carolina", "Florida", "Texas", "North Dakota", "Oregan", "Maine", "Michigan", "Virginia", "Pennsylvania", "New Hampshire", "Maryland", "Illinois", "Washington", "Delaware", "Nebraska", "Wisconsin", "Vermont", "Iowa", "Minnesota", "Rhode Island", "California", "Connecticut", "Hawaii", "New Jersey", "New York", "Massachusetts"],
    'GunLaws': [3, 2, 7, 10, 19, 22, 2, 4, 8, 11, 12, 22, 18, 6, 8, 6, 1, 7, 12, 30, 32, 5, 15, 15, 30, 30, 18, 10, 42, 11, 21, 25, 39, 9, 69, 70, 55, 41, 22, 23, 20, 24, 41, 53, 111, 89, 82, 80, 77, 103],
    'GunDeaths': [24.4, 24.2, 22.3, 22.2, 22.1, 22.3, 20.6, 19, 18.6, 19.3, 19.9, 18.4, 16.6, 15.8, 15.1, 14.9, 14.2, 13.7, 14.1, 15.3, 14.2, 13.1, 13.3, 12.8, 13.1, 12.7, 12.6, 12.4, 12.6, 11.5, 12.1, 11.7, 11.7, 10.7, 12.6, 10.8, 10.7, 9.9, 10.4, 10, 9.3, 9.1, 8.1, 4.6, 7.2, 5.3, 4.4, 4.1, 3.9, 3.4]
}
TableLawDeath = pd.DataFrame(LawDeath)
print(TableLawDeath)
# Out:
#              State  GunLaws  GunDeaths
# 0           Alaska        3       24.4
# 1      Mississippi        2       24.2
# 2          Wyoming        7       22.3
# 3          Alabama       10       22.2
# 4        Louisiana       19       22.1
# 5       New Mexico       22       22.3
# 6         Missouri        2       20.6
# 7          Montana        4       19.0
# 8         Oklahoma        8       18.6
# 9         Arkansas       11       19.3
# 10  South Carolina       12       19.9
# 11       Tennessee       22       18.4
# 12   West Virginia       18       16.6
# 13         Georgia        6       15.8
# 14        Ariozona        8       15.1
# 15        Kentucky        6       14.9
# 16           Idaho        1       14.2
# 17          Kansas        7       13.7
# 18         Indiana       12       14.1
# 19          Nevada       30       15.3
# 20        Colorado       32       14.2
# 21    South Dakota        5       13.1
# 22            Ohio       15       13.3
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
plt.scatter(TableLawDeath['GunLaws'], TableLawDeath['GunDeaths'], color='skyblue', edgecolor='black')
for i, txt in enumerate(TableLawDeath['State']):
    plt.annotate(txt, (TableLawDeath['GunLaws'][i], TableLawDeath['GunDeaths'][i]), fontsize=8, ha='right')

plt.xlabel('Number of Gun Laws per State')
plt.ylabel('Gun Deaths per 100,000 people')
plt.title('Relationship between Number of Gun Laws and Gun Deaths by State')
plt.grid(True, color='lightgrey', linestyle='--', linewidth=0.5)
plt.show()
